# %%
# %matplotlib nbagg
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt

k = 1 #Spring stiffness
m = 1 #Atomic mass 
a = 1 #Atomic spacing
#t = 0
#t = np.linspace(0,100,100) #Time
pi = np.pi #Pi
N = 100 #Number of atoms
n = np.linspace(0,N-1,N)

q_m = np.zeros(N)
for i in range (0,N):
    q_m[i] = (2*pi/a)*(i/N)
q_0 = pi

del_k = 0.15
a_m = np.zeros(N)
for i in range (0,N):
    a_m[i] = (1/(np.sqrt(pi)*del_k))*np.exp(-((q_m[i]-q_0)/del_k)**2)
    
w = np.zeros(N)
for i in range (0,N):
    w[i] = 2*np.sqrt(k/m)*np.abs(np.sin(q_m[i]*a/2))
    

u_nn = np.zeros((N,N))

fig, ax = plt.subplots(1, figsize = (8,4))
plt.suptitle('Wave packet')

def update_plot(time):
    
    """
    This function is linked to the slider and wil upload the wave package when the time is changed
    """
    ax.clear()
    u_nn = np.zeros((N,N))
    for i in range(0,N):
        for j in range (0,N):
            u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*time)
    u_n = np.zeros(N)
    u_n = u_nn.sum(axis = 0)
    
    ax.plot(n,u_n)
    ax.set_ylim(-20,20)
    

time = widgets.FloatSlider(min = 0, max = 100, value = 0, description = 'Time')

widgets.interactive(update_plot, time = time)
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">
# interactive(children=(FloatSlider(value=0.0, description='Time'), Output()), _dom_classes=('widget-interact',))

# %%
fig1, ax1 = plt.subplots(1, figsize = (8,4))
plt.plot(n,w)
plt.suptitle('w vs N')
plt.show()

fig2, ax2 = plt.subplots(1, figsize = (8,4))
plt.plot(q_m,w)
plt.suptitle('w vs k_m')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">
# <img src="data:image/png;base64,..." width="918.2608886026484">

# %%
# %matplotlib notebook
import matplotlib as plt
from matplotlib.animation import FuncAnimation

t = np.linspace(0,1000,10)

fig (ax1) = plt.subplots(1, figsize = (10,4))

def animate(B)
# Out:
#   File "<ipython-input-17-3617c2fba70c>", line 9
#     def animate(B)
#                   ^
# SyntaxError: invalid syntax

# %%
#T_0

u_nn_t_0 = np.zeros((N,N))
for i in range(0,N):
    for j in range (0,N):
        u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*0)
u_n_t_0 = np.zeros(N)
u_n_t_0 = u_nn.sum(axis = 0)

#T_1

u_nn_t_1 = np.zeros((N,N))
for i in range(0,N):
    for j in range (0,N):
        u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*0.1)
u_n_t_1 = np.zeros(N)
u_n_t_1 = u_nn.sum(axis = 0)

v_n = (u_n_t_1-u_n_t_0)/0.1

k = 1
#1st term
E_1 = (k/2)*(u_n_t_0[0]-u_n_t_0[N-1])**2
#2nd term
E_22 = np.zeros(N-1)
for i in range(0,N-1):
    E_22[i] = (u_n_t_0[i+1]-u_n_t_0[i])**2
E_2 = (k/2)*(E_22.sum())
#3rd term
E_33 = np.zeros(N)
for i in range(0,N):
    E_33[i] = v_n[i]**2
E_3 = (m/2)*(E_33.sum())

E = E_1+E_2+E_3

print(E)
# Out:
# 8537.79036867346

# %%
t = np.linspace(0,1000,101)
E = np.zeros(len(t))
for ii in range (0, len(t)):
    #T_0
    u_nn_t_0 = np.zeros((N,N))
    for i in range(0,N):
        for j in range (0,N):
            u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*t[ii])
    u_n_t_0 = np.zeros(N)
    u_n_t_0 = u_nn.sum(axis = 0)
    #T_1
    u_nn_t_1 = np.zeros((N,N))
    for i in range(0,N):
        for j in range (0,N):
            u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*(t[ii]+0.1))
    u_n_t_1 = np.zeros(N)
    u_n_t_1 = u_nn.sum(axis = 0)

    v_n = (u_n_t_1-u_n_t_0)/0.1

    k = 1
    #1st term
    E_1 = (k/2)*(u_n_t_0[0]-u_n_t_0[N-1])**2
    #2nd term
    E_22 = np.zeros(N-1)
    for i in range(0,N-1):
        E_22[i] = (u_n_t_0[i+1]-u_n_t_0[i])**2
    E_2 = (k/2)*(E_22.sum())
    #3rd term
    E_33 = np.zeros(N)
    for i in range(0,N):
        E_33[i] = v_n[i]**2
    E_3 = (m/2)*(E_33.sum())

    E[ii] = E_1+E_2+E_3

fig, ax = plt.subplots(1, figsize = (8,4))
plt.plot(t,E)
plt.suptitle('E vs t')
ax.set_ylim(0,np.max(E)*1.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">

# %%
Q = np.zeros(len(t))
for ii in range (0, len(t)):
    #T_0
    u_nn_t_0 = np.zeros((N,N))
    for i in range(0,N):
        for j in range (0,N):
            u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*t[ii])
    u_n_t_0 = np.zeros(N)
    u_n_t_0 = u_nn.sum(axis = 0)
    #T_1
    u_nn_t_1 = np.zeros((N,N))
    for i in range(0,N):
        for j in range (0,N):
            u_nn[i,j] = a_m[i]*np.cos(q_m[i]*n[j]*a-w[i]*(t[ii]+0.1))
    u_n_t_1 = np.zeros(N)
    u_n_t_1 = u_nn.sum(axis = 0)

    v_n = (u_n_t_1-u_n_t_0)/0.1
    
    #1st term
    Q_1 = (1/N*a)*(k*a/2)*(u_n_t_0[0]-u_n_t_0[N-1])*(v_n[0]+v_n[N-1])
    #2nd term
    Q_22 = np.zeros(N-1)
    for i in range (0,N-1):
        Q_22[i] = (u_n_t_0[i+1]-u_n_t_0[i])*(v_n[i+1]-v_n[i])
    Q_2 = (1/N*a)*(k*a/2)*(Q_22.sum())
    
    Q[ii] = Q_1 + Q_2

fig, ax = plt.subplots(1, figsize = (8,4))
plt.plot(t,Q)
plt.suptitle('Q vs t')
ax.set_ylim(np.min(Q)*1.1,np.max(Q)*1.1)
plt.show()
plt.savefig('a.jpg')
# Out:
# <img src="data:image/png;base64,..." width="918.2608886026484">
